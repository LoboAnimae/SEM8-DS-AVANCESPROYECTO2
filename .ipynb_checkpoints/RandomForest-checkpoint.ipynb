# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, plot_roc_curve
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv('./vaccination-data.csv')
data.head()
# Out:
#   iso_code continent     location       date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2/24/2020          5.0        5.0
# 1      AFG      Asia  Afghanistan  2/25/2020          5.0        0.0
# 2      AFG      Asia  Afghanistan  2/26/2020          5.0        0.0
# 3      AFG      Asia  Afghanistan  2/27/2020          5.0        0.0
# 4      AFG      Asia  Afghanistan  2/28/2020          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
data.dtypes
# Out:
# iso_code                       object
# continent                      object
# location                       object
# date                           object
# total_cases                   float64
#                                ...
# handwashing_facilities        float64
# hospital_beds_per_thousand    float64
# life_expectancy               float64
# human_development_index       float64
# excess_mortality              float64
# Length: 62, dtype: object

# %%
data.dropna(subset=['new_deaths_per_million'], inplace=True)

# %%
label_encoder = LabelEncoder()
data['iso_code'] = label_encoder.fit_transform(data['iso_code'])

# %%
X = data[['date', 'iso_code', 'new_cases_per_million', 'new_vaccinations', 'total_vaccinations', 'population_density', 'median_age']]
y = data['new_deaths_per_million']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %%
# Random Forest Parameters
# See the excel for previous results
max_depth = 2
random_state = 101  
n_estimators = 10    # number of trees
min_samples_split = 10 # minimum samples to split a node
min_samples_leaf = 3  # minimum samples to be a leaf
